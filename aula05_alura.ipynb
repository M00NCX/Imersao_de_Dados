# %% [markdown]
# <a href="https://colab.research.google.com/github/M00NCX/Imersao_de_Dados/blob/main/aula05_alura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 3ª Edição da Imersão Dados - Alura é para quem quer acelerar os conhecimentos em Ciência de Dados, utilizando tecnologias alinhadas ao mercado e desenvolvendo projetos com dados do mundo real. |Utilizando conehcimentos em Lógica da Programação, Python, Data Science e +

# %%
## AULA 01

# %% [markdown]
# ####Desafio 01: Investigar por que a classe tratamento é tão desbalanceada? | **OK**
#
# ####Desafio 02: Plotar as 5 últimas linhas da tabela.  | **OK**
#
# ####Desafio 03: Proporção das classes tratamento. | **OK**
#
# ####Desafio 04: Quantos tipos de drogas foram investigadas? | **OK**
#
# ####Desafio 05: Procurar na documentação o método query. | **OK**
#
# ####Desafio 06: Renomear as colunas tirando o hífen. | **OK**
#
# ####Desafio 07: Deixar os gráficos bonitões. (Matplotlib.pyplot) | **OK**
#
# ####Desafio 08: Resumo do que você aprendeu com os dados:
# #### **Pode-se observar que:**
# #### **- Há dois tipos de tratamentos, o com drogas e o com controle, que somam 23.214 amostras;**
# #### **- Com controle: Somente um tipo de droga, sendo este o "cacb2b860", e 1.866 ao total;**
# #### **- Com drogas: 3.289 tipos de drogas usadas em 21.948 amostras, ao total;**
# #### **- Há dois tipos de doses, D1 e D2;**
# #### **- Os períodos do tempo de exposição são divididos em 24, 48 e 72 horas;**
# #### **- Nota: As observações feitas não querem dizer verdade absoluta, pois foram as análises que eu consegui chegar, podendo ser verídicas ou não.**
#
# #### - Aprendi a criar gráficos de uma base de dados e personalizar algumas variáveis, como: cor, fonte, tamanho, posição, legenda, etc;
# #### - Fazer um "refinamento" dos dados com .value_counts() e .unique();

# %%
import pandas as pd

import matplotlib.pyplot as plt

import numpy as np

import seaborn as sns


url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados.shape
# Out:
# (23814, 877)

# %%
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %%
## DESAFIO 01
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados.tail()

## DESAFIO 02
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
dados['droga'].value_counts(normalize = True)
# Out:
# cacb2b860    0.078357
# 87d714366    0.030150
# 9f80f3f77    0.010330
# 8b87a7a83    0.008524
# 5628cb3ee    0.008482
#                ...
# 00dba5599    0.000042
# 91a585117    0.000042
# ddb7e0c01    0.000042
# 23458e56a    0.000042
# a67f38a69    0.000042
# Name: droga, Length: 3289, dtype: float64

# %%
## DESAFIO 03 + 07

tipos_de_tratamento = dados.tratamento.value_counts()
labels = (dados.tratamento.unique())
explode = (0, 0.1)
cores = ['salmon', 'springgreen']


plt.title('Tipos de Tratamentos', fontsize=16, fontweight='bold')
plt.pie(tipos_de_tratamento, labels=labels, explode=explode, autopct='%2.2f%%', colors=cores)
plt.tight_layout()
plt.axis('equal')
plt.show()

# %%
## DESAFIO 07
dados['tempo'].value_counts().plot.bar()
tempo_hrs = dados.tempo.value_counts()

plt.title('Tempo de exposição', fontsize=16, fontweight='bold')
plt.bar(tempo_hrs, height= 0.6, width=0.8)

tempo_hrs.plot.bar(color=['springgreen','mediumseagreen','forestgreen'])
plt.xlabel('Tempo em horas', fontsize=12)
plt.ylabel('Quantidade de tratamentos', fontsize=12)
plt.tight_layout()
plt.show()

# %%
dados_filtrados = dados[dados['g-0'] > 0]

# %%
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %%
## DESAFIO 04
dados['droga'].nunique()
# Out:
# 3289

# %%
## DESAFIO 05
dados.query('tratamento == "com_droga"')
# Out:
#                  id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...        ...    ...  ...  ...     ...     ...     ...     ...
# 23808  id_fff8c2444  com_droga     72   D1  ... -0.7415  0.8413 -0.4259  0.2434
# 23809  id_fffb1ceed  com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c  com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23812  id_fffcb9e7c  com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b  com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# ...

# %%
dados.query('tratamento == "com_controle"')
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# 47     id_008a986b7  com_controle     48   D2  ... -0.4979  0.5281 -0.9245 -0.9367
# 63     id_009d8340f  com_controle     24   D2  ...  0.0949  0.2000 -0.4326  0.9364
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23729  id_ff1f9e5fc  com_controle     24   D1  ...  0.2131 -0.1419 -0.2422  0.0457
# 23747  id_ff469c482  com_controle     72   D1  ... -0.9630  0.8872 -0.0742 -0.6777
# 23768  id_ff89331ca  com_controle     72   D2  ...  0.9517 -0.8110 -0.1748 -0.3626
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# ...

# %%
dados['tratamento'].nunique()
# Out:
# 2

# %%
## DESAFIO 06

nv_dados = dados.copy()
nv_dados.columns =[column.replace("-", "") for column in nv_dados.columns]
nv_dados.query('g0 > 0')
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6      id_001bd861f     com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23807  id_fff7e6992     com_droga     48   D1  ...  0.3738  0.8636  0.4494  0.1218
# 23808  id_fff8c2444     com_droga     72   D1  ... -0.7415  0.8413 -0.4259  0.2434
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
##AULA 02

# %% [markdown]
# ####**DESAFIO 01: Ordenar o gráfico countplot; | OK**
# ####**DESAFIO 02: Melhorar a visualização alterando o tamanho da fonte...; | OK**
# ####**DESAFIO 03: Plotar os histogramas com seaborn; | OK**
# ####**DESAFIO 04: Estudar sobre as estatísticas retornadas no .describe(); | OK** - O .describe() retorna informações sobre os dados, tal como o máximo(max); mínimo (min); média (mean); quantidade (count); percentis (25%, 50%, 75%); desvio padrão (std).
# ####**DESAFIO 05: Refletir sobre a manipulação do tamanho das visualizações; | OK** - O tamnho das visualizações do gráfico é extremamente importante, uma vez que, dependendo da quantidade de dados e do intervalo entre eles, pode ficar indecifrável as informações que deseja-se obter. Desse modo, é importante ajustar a escala de visualização para uma melhor compreensão.
# ####**DESAFIO 06: Fazer outras análises com o bloxplot e até com o histograma; | OK**
# ####**DESAFIO 07: Resumo do que você aprendeu com os dados:**
# - Distribuição dos valores G e C;
# - Como usar seaborn para melhorar a visualização dos gráficos;
# - Alguns conceitos de estatística;
#
#
#
# #####**GLOSSÁRIO:**
#
# *   G = Genes;
# *   C = Tipos celulares;
# *   Desvio Padrão = Quanto mais próximo de 0, mais homogêneo são os dados.

# %%
mapa={'droga':'composto'}
dados.rename(columns= mapa, inplace=True)

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
cod_compostos = dados['composto'].value_counts().index [0:5]

# %%
cod_compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
dados.query('composto in @cod_compostos')
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
##DESAFIO 01 + 02
ax = sns.countplot(x='composto', data=dados.query('composto in @cod_compostos'), palette="rocket", order=cod_compostos)
ax.set_title('Top 5 Compostos', fontsize=16, fontweight='bold')
ax.set_ylabel('Quantidade', fontsize=14)
ax.set_xlabel('Composto', fontsize=14)
sns.set_style(style="whitegrid")

plt.show()

# %%
len(dados['g-0'].unique())
# Out:
# 14367

# %%
dados['g-0'].min()
# Out:
# -5.513

# %%
dados['g-0'].max()
# Out:
# 10.0

# %%
ax0 = dados['g-0'].hist(bins = 100)
ax0.set_title('G-0', fontsize = 16, fontweight='bold')
ax0.set_ylabel('Quantidade', fontsize=14)
ax0.set_xlabel('Intervalo', fontsize=14)
plt.show()

# %%
ax70 = dados['g-70'].hist(bins = 80)
ax70.set_title('G-70', fontsize = 16, fontweight='bold')
ax70.set_ylabel('Quantidade', fontsize=14)
ax70.set_xlabel('Intervalo', fontsize=14)
plt.show()

# %%
ax18 = dados['g-18'].hist(bins = 80)
ax18.set_title('G-18', fontsize = 16, fontweight='bold')
ax18.set_ylabel('Quantidade', fontsize=14)
ax18.set_xlabel('Intervalo', fontsize=14)
plt.show()

# %%
##DESAFIO 03
ax99 = dados['c-99'].hist(bins = 100)
ax99.set_title('C-99', fontsize = 16, fontweight='bold')
ax99.set_ylabel('Quantidade', fontsize=14)
ax99.set_xlabel('Intervalo', fontsize=14)
plt.show()

# %%
axt = dados['tratamento'].hist()
axt.set_title('Histograma Tratamento', fontsize = 16, fontweight='bold')
axt.set_ylabel('Quantidade', fontsize=14)
plt.show()

# %%
dados['g-0'].mean()
# Out:
# 0.24836629293692816

# %%
dados.describe()
# Out:
#               tempo           g-0  ...          c-98          c-99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
dados[['g-0', 'g-1']]
# Out:
#           g-0     g-1
# 0      1.0620  0.5577
# 1      0.0743  0.4087
# 2      0.6280  0.5817
# 3     -0.5138 -0.2491
# 4     -0.3254 -0.4009
# ...       ...     ...
# 23809  0.1394 -0.0636
# 23810 -1.3260  0.3478
# 23811  0.3942  0.3756
# 23812  0.6660  0.2324
# 23813 -0.8598  1.0240
#
# [23814 rows x 2 columns]

# %%
dados.loc[:,'g-0':'g-771'].describe()
# Out:
#                 g-0           g-1  ...         g-770         g-771
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean       0.248366     -0.095684  ...     -0.219210      0.101524
# std        1.393399      0.812363  ...      1.326193      1.417674
# min       -5.513000     -5.737000  ...    -10.000000    -10.000000
# 25%       -0.473075     -0.562200  ...     -0.554400     -0.523800
# 50%       -0.008850     -0.046600  ...      0.028700     -0.006500
# 75%        0.525700      0.403075  ...      0.496400      0.536950
# max       10.000000      5.039000  ...     10.000000     10.000000
#
# [8 rows x 772 columns]

# %%
## .T inverte linhas e colunas
hig = dados.loc[:,'g-0':'g-771'].describe().T['mean'].hist(bins=50)
hig.set_title('Histograma G0 - G771', fontsize=16, fontweight='bold')
hig.set_xlabel('Intevalo', fontsize=14)
hig.set_ylabel('Quantidade', fontsize=14)
plt.show()

# %%
higm = dados.loc[:,'g-0':'g-771'].describe().T['min'].hist(bins=30)
higm.set_title('Mínimos G0 - G771', fontsize=16, fontweight='bold')
higm.set_xlabel('Intevalo', fontsize=14)
higm.set_ylabel('Quantidade', fontsize=14)
plt.show()

# %%
higma = dados.loc[:,'g-0':'g-771'].describe().T['max'].hist(bins=30)
higma.set_title('Máximo G0 - G771', fontsize=16, fontweight='bold')
higma.set_xlabel('Intevalo', fontsize=14)
higma.set_ylabel('Quantidade', fontsize=14)
plt.show()

# %%
hicme = dados.loc[:,'c-0':'c-99'].describe().T['mean'].hist(bins=50)
hicme.set_title('Média C0 - C99', fontsize=16, fontweight='bold')
hicme.set_xlabel('Intevalo', fontsize=14)
hicme.set_ylabel('Quantidade', fontsize=14)
plt.show()

# %% [markdown]
# Boxplot, exemplificação:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# O quartil 1 é o número médio do intervalo à esquerda da mediana.
#
# O quartil 3 é o número médio do intervalo à direita da mediana.

# %%
plt.figure(figsize=(8,6))
bxg = sns.boxplot(y='g-0' , x='tratamento', data=dados, palette='Blues')
bxg.set_xlabel('Tratamento')
bxg.set_title('Boxplot G-0 x Tratamento', fontsize=14, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(8,6))
bxc = sns.boxplot(y='c-0' , x='tratamento', data=dados, palette='Purples')
bxc.set_xlabel('Tratamento')
bxc.set_title('Boxplot C-0 x Tratamento', fontsize=14, fontweight='bold')
plt.show()

# %%
fig, (dg, dc) = plt.subplots(1, 2, figsize=(10,8))

sns.boxplot(y='g-0' , x='dose', data=dados, palette = 'crest', ax=dg)
dg.set_xlabel('Dose')
dg.set_title('Boxplot G-0 x Dose', fontsize=14, fontweight='bold')

sns.boxplot(y='c-0' , x='dose', data=dados, palette = 'viridis', ax=dc)
dc.set_xlabel('Dose')
dc.set_title('Boxplot C-0 x Dose', fontsize=14, fontweight='bold')

plt.show()

# %%
dt = sns.boxplot(y='g-0' , x='tempo', data=dados, palette='gray')
dt.set_xlabel('Tempo(h)')
dt.set_ylabel('G-0')
dt.set_title('G0 x Tempo', fontsize=14, fontweight='bold')
plt.show()

# %%
## AULA 03

# %% [markdown]
# ####**DESAFIO 01: Criar tabelas de frequência com o pandas.groupby(); |**
# ####**DESAFIO 02: Normalizar o crosstab pela coluna; |**
# ####**DESAFIO 03: Explorar outros agregadores; |**
# ####**DESAFIO 04: Explorar o melt; |**
# ####**DESAFIO 05: Calcular e analisar a correlação entre G e C; |**
# ####**DESAFIO 06: Estudar o código que plota a matriz de correlação (heatmap); |**
# ####**DESAFIO 07: Refeltir sobre os efeitros biológicos da correlação; |**
# ####**DESAFIO 08: Resumo o que você aprendeu com os dados; |**
#
# *   Aparetemente a correlação entr G e C é, em geral, inversamente proporsional | Correlação não é casualidade;
# *   Analisar gráficos boxplot, heatmap, lmplot;

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
##Frequência dos dados selecionados
pd.crosstab(dados['dose'], dados['tempo'])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
## proporções
## DESAFIO 02
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize='index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize='columns')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.161308   0.163341
#      48         0.183816   0.182750
#      72         0.164523   0.164024
# D2   24         0.163451   0.163158
#      48         0.163451   0.163614
#      72         0.163451   0.163113

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g-0'], aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g-0'], aggfunc='max')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24            3.226      9.908
#      48            3.423     10.000
#      72            2.584      9.355
# D2   24            2.601      7.167
#      48            4.335     10.000
#      72            4.670     10.000

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g-0'], aggfunc='min')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24           -2.370     -5.183
#      48           -3.276     -5.420
#      72           -2.086     -5.261
# D2   24           -2.135     -5.233
#      48           -4.859     -4.567
#      72           -1.909     -5.513

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g-0'], aggfunc='median')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24          -0.2912    0.02700
#      48          -0.2145    0.01620
#      72          -0.3655    0.02615
# D2   24           0.0096   -0.02610
#      48          -0.0506   -0.02960
#      72           0.0528    0.00015

# %%
dados[['g-0', 'g-3']]
# Out:
#           g-0     g-3
# 0      1.0620 -0.6208
# 1      0.0743  0.0604
# 2      0.6280 -0.0764
# 3     -0.5138  0.5288
# 4     -0.3254  0.6919
# ...       ...     ...
# 23809  0.1394 -0.5080
# 23810 -1.3260  0.9905
# 23811  0.3942 -0.7389
# 23812  0.6660  0.2044
# 23813 -0.8598  0.7952
#
# [23814 rows x 2 columns]

# %%
## Desafio 01 - 

dados.groupby(['dose', 'tempo'] )['tratamento'].value_counts().unstack()
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
dados.groupby(['dose', 'tratamento'] )['tempo'].value_counts().unstack()
# Out:
# tempo                24    48    72
# dose tratamento
# D1   com_controle   301   343   307
#      com_droga     3585  4011  3600
# D2   com_controle   305   305   305
#      com_droga     3581  3591  3580

# %%
dados.groupby(['dose', 'tempo', 'tratamento'])['g-0'].mean().unstack()
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
##dropna() = Retira o NaN(not a number)

dados.groupby(['dose', 'c-0'] )['tempo'].value_counts().unstack().dropna()
# Out:
# tempo         24   48   72
# dose c-0
# D1   -2.068  1.0  1.0  1.0
#      -1.738  1.0  1.0  1.0
#      -1.417  1.0  1.0  1.0
#      -1.406  1.0  1.0  1.0
#      -1.404  1.0  1.0  1.0
# ...          ...  ...  ...
# D2    1.291  1.0  1.0  1.0
#       1.323  1.0  1.0  1.0
#       1.339  1.0  2.0  1.0
#       1.359  1.0  1.0  1.0
#       1.401  1.0  1.0  3.0
#
# [235 rows x 3 columns]

# %%
dados.melt()
# Out:
#          variable         value
# 0              id  id_000644bb2
# 1              id  id_000779bfc
# 2              id  id_000a6266a
# 3              id  id_0015fd391
# 4              id  id_001626bd3
# ...           ...           ...
# 20884873     c-99         0.468
# 20884874     c-99        0.3689
# 20884875     c-99        0.3808
# 20884876     c-99         0.074
# 20884877     c-99        -4.252
#
# [20884878 rows x 2 columns]

# %%
pd.melt(dados, id_vars=['tratamento'], value_vars=['tempo','dose'])
# Out:
#          tratamento variable value
# 0         com_droga    tempo    24
# 1         com_droga    tempo    72
# 2         com_droga    tempo    48
# 3         com_droga    tempo    48
# 4         com_droga    tempo    72
# ...             ...      ...   ...
# 47623     com_droga     dose    D2
# 47624     com_droga     dose    D2
# 47625  com_controle     dose    D2
# 47626     com_droga     dose    D1
# 47627     com_droga     dose    D1
#
# [47628 rows x 3 columns]

# %%
pd.melt(dados,id_vars=['dose','tempo','tratamento'],value_vars=['g-0', 'c-0'])
# Out:
#       dose  tempo    tratamento variable   value
# 0       D1     24     com_droga      g-0  1.0620
# 1       D1     72     com_droga      g-0  0.0743
# 2       D1     48     com_droga      g-0  0.6280
# 3       D1     48     com_droga      g-0 -0.5138
# 4       D2     72     com_droga      g-0 -0.3254
# ...    ...    ...           ...      ...     ...
# 47623   D2     24     com_droga      c-0  0.4224
# 47624   D2     24     com_droga      c-0  0.2144
# 47625   D2     48  com_controle      c-0  1.0650
# 47626   D1     24     com_droga      c-0  0.5377
# 47627   D1     72     com_droga      c-0 -2.3890
#
# [47628 rows x 5 columns]

# %%
sns.scatterplot(x='g-0', y='g-3', data=dados)
plt.show()

# %%
##Quando G0 aumenta G8 diminui
sns.scatterplot(x='g-0', y='g-8', data=dados)

# %%
##Linha de tendência
sns.lmplot(data=dados, x='g-0', y='g-8', line_kws={'color':'red'})
plt.show()

# %%
sns.lmplot(data=dados, x='g-0', y='g-8', line_kws={'color':'red'}, col='tratamento', row='tempo')
plt.show()

##Quanto maior o tempo mais a curva fica inclinada no tratamento com drogas;
##Tratamento com controle está "estável";
## Correlação não é causa;

# %%
sns.lmplot(data=dados, x='g-0', y='c-0', line_kws={'color':'red'})
plt.show()

# %%
sns.lmplot(data=dados, x='g-18', y='c-18', line_kws={'color':'red'})
plt.show()

# %%
## .corr = correlação | Correlação das expressões gênicas
## Valores próximos de -1 ou +1 = variáveis bem correlacionadas / Valores próximos de 0 = variáveis "não correlacionadas"
## Negativos = inversamente | Positiva = diretamente
dados.loc[:, 'g-0':'g-771'].corr()
# Out:
#             g-0       g-1       g-2  ...     g-769     g-770     g-771
# g-0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g-1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g-2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g-3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g-4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...         ...       ...       ...  ...       ...       ...       ...
# g-767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g-768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g-769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g-770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g-771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %%
import numpy as np

corr = dados.loc[:, 'g-0':'g-50'].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %%
corr_celular = dados.loc[:, 'c-0':'c-50'].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_celular, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_celular, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %%
corrcg = dados.loc[:,'g-0':'c-99'].corr()
corrcg.loc[:'g-49','c-0':]
# Out:
#            c-0       c-1       c-2  ...      c-97      c-98      c-99
# g-0  -0.624116 -0.624810 -0.639789  ... -0.622840 -0.640484 -0.609238
# g-1  -0.037405 -0.030558 -0.039616  ... -0.008487 -0.002824 -0.002308
# g-2  -0.168656 -0.178692 -0.176733  ... -0.178812 -0.170152 -0.172124
# g-3  -0.037342 -0.093505 -0.085298  ... -0.049951 -0.079855 -0.037579
# g-4  -0.403545 -0.379840 -0.392841  ... -0.394904 -0.366693 -0.390581
# g-5   0.209358  0.198890  0.211988  ...  0.193907  0.179097  0.192385
# g-6  -0.103316 -0.079528 -0.078782  ... -0.095448 -0.084408 -0.079813
# g-7   0.486478  0.553859  0.565002  ...  0.543828  0.529412  0.489600
# g-8   0.621422  0.601678  0.597372  ...  0.602902  0.596262  0.568512
# g-9   0.435235  0.475424  0.488331  ...  0.467187  0.444415  0.441176
# g-10  0.586035  0.643461  0.640281  ...  0.626977  0.596092  0.576789
# g-11 -0.231425 -0.270409 -0.276064  ... -0.251709 -0.225101 -0.215920
# ...

# %%
corrcg = corrcg.loc['c-0':'c-15', 'g-0':'g-15']


mask = np.triu(np.ones_like(corrcg, dtype=bool))

f, ax = plt.subplots(figsize=(15, 10))
ax.set_title('C x G')

# Gerando um mapa de cores divergentes personalizado
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Desenhando o mapa de calor com a máscara e a proporção correta
sns.heatmap(corrcg, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.show()

# %%
## AULA 04

# %% [markdown]
# #####**DESAFIO 01: Encontrar o top 10 das ações do MOA (inibitor, agonista,...); |**
# #####**DESAFIO 02: Criar a coluna "eh_controle" para quando na linha tratamento == com_controle; |**
# #####**DESAFIO 03: Criar três colunas para indicar o tempo 24, 48, 72 |True or False; |**
# #####**DESAFIO 04: Estudar sobre combinações de dataframes https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html;|**
# #####**DESAFIO 05:Fazer análise mais detalhada considerando tempo e dose para comparar as distribuições (escolher uma droga e comparar com o controle);|**
# #####**DESAFIO 06: Descobrir se tempo algum composto que dependendo da configuração do experimento, ativa ou não algum MOA;|**
# #####**DESAFIO 07: Descobrir se tempo algum composto que dependendo da configuração do experimento, ativa MOAs diferentes;|**
# #####**DESAFIO 08: Resumo do que você aprendeu com os dados:|**
# * Tem-se 5 ativadores: potassium_channel_activator, nrf2_activator, caspase_activator, ampk_activator, adenylyl_cyclase_activator;
# * Função merge;
# * Mecanismos mais ativados;

# %%
dados_resultados = pd.read_csv('https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_resultados.csv?raw=true')
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados_resultados.describe()
# Out:
#        5-alpha_reductase_inhibitor  ...  wnt_inhibitor
# count                 23814.000000  ...   23814.000000
# mean                      0.000714  ...       0.001260
# std                       0.026709  ...       0.035472
# min                       0.000000  ...       0.000000
# 25%                       0.000000  ...       0.000000
# 50%                       0.000000  ...       0.000000
# 75%                       0.000000  ...       0.000000
# max                       1.000000  ...       1.000000
#
# [8 rows x 206 columns]

# %%
dados_resultados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23814 entries, 0 to 23813
# Columns: 207 entries, id to wnt_inhibitor
# dtypes: int64(206), object(1)
# memory usage: 37.6+ MB

# %%
## 0 = mecanismo não foi ativado naquele id
## 1 = mecanismo foi ativado naquele id

# %%
dados_resultados['acat_inhibitor'].unique()
# Out:
# array([0, 1])

# %%
dados_resultados['acetylcholine_receptor_agonist'].unique()
# Out:
# array([0, 1])

# %%
contagem_moa = dados_resultados.select_dtypes('int64').sum().sort_values(ascending=False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
dados_resultados.drop('id', axis = 1).sum(axis=1)
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados_resultados['n_moa'] = dados_resultados.drop('id', axis = 1).sum(axis=1)

# %%
dados_resultados['ativo_moa'] = (dados_resultados['n_moa'] !=0)
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
dados_combinados= pd.merge(dados, dados_resultados[['id','n_moa', 'ativo_moa']], on='id')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %%
dados_combinados.query('tratamento == "com_droga"')['ativo_moa'].value_counts()
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %%
composto_principal = dados_combinados['composto'].value_counts().index[:5]
plt.figure(figsize = (12,10))
sns.boxplot(data = dados_combinados.query('composto in @composto_principal'), y= 'g-0', x ='composto', hue='ativo_moa')

# %%
contagem_moa.filter(like='inhibitor').index[:10]
# Out:
# Index(['nfkb_inhibitor', 'proteasome_inhibitor', 'cyclooxygenase_inhibitor',
#        'dna_inhibitor', 'cdk_inhibitor', 'egfr_inhibitor', 'tubulin_inhibitor',
#        'pdgfr_inhibitor', 'hmgcr_inhibitor', 'flt3_inhibitor'],
#       dtype='object')

# %%
contagem_moa.filter(like='antagonist').index[:10]
# Out:
# Index(['dopamine_receptor_antagonist', 'serotonin_receptor_antagonist',
#        'glutamate_receptor_antagonist', 'adrenergic_receptor_antagonist',
#        'acetylcholine_receptor_antagonist', 'histamine_receptor_antagonist',
#        'gaba_receptor_antagonist', 'cc_chemokine_receptor_antagonist',
#        'potassium_channel_antagonist', 'adenosine_receptor_antagonist'],
#       dtype='object')

# %%
 agonista_top= contagem_moa.filter(like='agonist').index[:10]
 agonista_top
# Out:
# Index(['dopamine_receptor_antagonist', 'serotonin_receptor_antagonist',
#        'glutamate_receptor_antagonist', 'adrenergic_receptor_antagonist',
#        'acetylcholine_receptor_antagonist', 'adrenergic_receptor_agonist',
#        'glucocorticoid_receptor_agonist', 'histamine_receptor_antagonist',
#        'serotonin_receptor_agonist', 'acetylcholine_receptor_agonist'],
#       dtype='object')

# %%
ativador = contagem_moa.filter(like='activator')
ativador
# Out:
# potassium_channel_activator    55
# nrf2_activator                 18
# caspase_activator              18
# ampk_activator                 12
# adenylyl_cyclase_activator     12
# dtype: int64

# %%
contagem_moa = dados_resultados.drop(['id','n_moa','ativo_moa'], axis=1).sum().sort_values(ascending=False).reset_index()
contagem_moa.columns = ['MOA', 'quantidade']
contagem_moa
# Out:
#                                             MOA  quantidade
# 0                                nfkb_inhibitor         832
# 1                          proteasome_inhibitor         726
# 2                      cyclooxygenase_inhibitor         435
# 3                  dopamine_receptor_antagonist         424
# 4                 serotonin_receptor_antagonist         404
# ..                                          ...         ...
# 201               protein_phosphatase_inhibitor           6
# 202                         autotaxin_inhibitor           6
# 203                                    diuretic           6
# 204                             erbb2_inhibitor           1
# 205  atp-sensitive_potassium_channel_antagonist           1
#
# [206 rows x 2 columns]

# %%
tipo_MOA = []
moa_split = contagem_moa['MOA'].str.split('_')
for row in moa_split:
    tipo_MOA.append(row[-1])
tipo_MOA[:10]
contagem_moa['tipo_MOA'] = tipo_MOA

# %%
##DESAFIO 01
top_moas = contagem_moa.groupby('tipo_MOA').agg({'quantidade':'sum'}).sort_values('quantidade', ascending=False).head(10).reset_index()
top_moas
# Out:
#             tipo_MOA  quantidade
# 0          inhibitor        9693
# 1         antagonist        3449
# 2            agonist        2330
# 3            blocker         323
# 4              agent         150
# 5          activator         115
# 6              local          80
# 7        antioxidant          73
# 8  anti-inflammatory          73
# 9  immunosuppressant          73

# %%
fig, ax = plt.subplots(figsize = (18, 10))
sns.barplot(x = "tipo_MOA", y = 'quantidade', data = top_moas, palette='rocket')
ax.set_title('Top 10 MOAs ', fontsize = "16")
ax.set_ylabel("Quantidade", fontsize = 14)
ax.set_xlabel("MOAs", fontsize = 14)
plt.show()

# %%
## DESAFIO 02

(dados_combinados['tratamento'] == 'com_controle')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 23809    False
# 23810    False
# 23811     True
# 23812    False
# 23813    False
# Name: tratamento, Length: 23814, dtype: bool

# %%
dados_combinados['eh_contole'] = (dados_combinados['tratamento'] == 'com_controle')
dados_combinados.tail(8)
# Out:
#                  id    tratamento  tempo  ... n_moa ativo_moa  eh_contole
# 23806  id_fff790a17     com_droga     48  ...     0     False       False
# 23807  id_fff7e6992     com_droga     48  ...     1      True       False
# 23808  id_fff8c2444     com_droga     72  ...     1      True       False
# 23809  id_fffb1ceed     com_droga     24  ...     1      True       False
# 23810  id_fffb70c0c     com_droga     24  ...     1      True       False
# 23811  id_fffc1c3f4  com_controle     48  ...     0     False        True
# 23812  id_fffcb9e7c     com_droga     24  ...     1      True       False
# 23813  id_ffffdd77b     com_droga     72  ...     0     False       False
#
# [8 rows x 880 columns]

# %%
dados_combinados['tempo24'] = (dados_combinados['tempo'] == 24)
dados_combinados['tempo48'] = (dados_combinados['tempo'] == 48)
dados_combinados['tempo72'] = (dados_combinados['tempo'] == 72)
dados_combinados.head(8)
# Out:
#              id tratamento  tempo dose  ... eh_contole  tempo24  tempo48  tempo72
# 0  id_000644bb2  com_droga     24   D1  ...      False     True    False    False
# 1  id_000779bfc  com_droga     72   D1  ...      False    False    False     True
# 2  id_000a6266a  com_droga     48   D1  ...      False    False     True    False
# 3  id_0015fd391  com_droga     48   D1  ...      False    False     True    False
# 4  id_001626bd3  com_droga     72   D2  ...      False    False    False     True
# 5  id_001762a82  com_droga     24   D1  ...      False     True    False    False
# 6  id_001bd861f  com_droga     24   D2  ...      False     True    False    False
# 7  id_0020d0484  com_droga     48   D1  ...      False    False     True    False
#
# [8 rows x 883 columns]

# %%
##Todos as drogas do 1º composto foram ativadas
dados_combinados.query('composto == "87d714366"' )['ativo_moa'].value_counts()
# Out:
# True    718
# Name: ativo_moa, dtype: int64

# %%
##Demonstração que a classe "com_controle" não foi ativo
dados_combinados.query('composto == "cacb2b860"' )['ativo_moa'].value_counts()
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
## Comparação de 4 compostos com droga vs o de controle (central)
plt.figure(figsize=(16,6))

plt.subplot(1,2,1)
sns.boxplot(data=dados.query('composto in @composto_principal'), 
            y='g-0', x='composto', hue='dose');

plt.subplot(1,2,2)
sns.boxplot(data=dados.query('composto in @composto_principal'), 
            y='g-0', x='composto', hue='tempo');
plt.show()

# %%
## Pode-se usar merge e concat para mesclar dados diferenciados

# %%
df_moa = dados_combinados.drop(dados_combinados.columns.difference(['composto','n_moa']), 1)
df_moa
# Out:
#         composto  n_moa
# 0      b68db1d53      1
# 1      df89a8e5a      0
# 2      18bb41b2c      3
# 3      8c7f86626      0
# 4      7cbed3131      1
# ...          ...    ...
# 23809  df1d0a5a1      1
# 23810  ecf3b6b74      1
# 23811  cacb2b860      0
# 23812  8b87a7a83      1
# 23813  972f41291      0
#
# [23814 rows x 2 columns]

# %%
moadiferente = dados_combinados.groupby(['composto'])['n_moa'].nunique().reset_index()
moadiferente.sort_values('n_moa')
# Out:
#        composto  n_moa
# 0     00199ff52      1
# 2186  afa502729      1
# 2187  afafe3ca9      1
# 2188  afd0dbace      1
# 2189  afed0fc6d      1
# ...         ...    ...
# 1099  5aa46f542      1
# 1100  5ab0bda1e      1
# 1101  5ab704064      1
# 1091  597779c01      1
# 3288  fff7d208d      1
#
# [3289 rows x 2 columns]

# %%
dados_combinados.groupby('composto').ativo_moa.mean().value_counts()
# Out:
# True     2076
# False    1213
# Name: ativo_moa, dtype: int64

# %%
## Ativação de MOAs diferentes
pd.crosstab([dados_combinados['n_moa'], dados_combinados['dose']],dados_combinados['tempo']).head()
# Out:
# tempo         24    48    72
# n_moa dose
# 0     D1    1522  1722  1531
#       D2    1532  1531  1529
# 1     D1    2050  2283  2056
#       D2    2045  2052  2046
# 2     D1     255   278   258

# %%
# Aula 05
## Machine learning

# %% [markdown]
# #####**DESAFIO 01: Tente outros modelos ou mude parâmetros dos modelos que testamos em aula; |**
# #####**DESAFIO 02: Estude a documentação do Sklearn; |**
# #####**DESAFIO 03: Pesquisar o fluxograma "Choosing the right estimator"; |**
# #####**DESAFIO 04: Teste outras perguntas de classificação; |**
# #####**DESAFIO 05: Escolha a droga mais utilizada e tente criar um modelo para prever esta label; |**
# #####**DESAFIO 06: Resumo do que você aprendeu com os dados: |**
#
# *   Utilização de Marchine Learning;
# *   Overfit;

# %%
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ... eh_contole  tempo24  tempo48  tempo72
# 0  id_000644bb2  com_droga     24   D1  ...      False     True    False    False
# 1  id_000779bfc  com_droga     72   D1  ...      False    False    False     True
# 2  id_000a6266a  com_droga     48   D1  ...      False    False     True    False
# 3  id_0015fd391  com_droga     48   D1  ...      False    False     True    False
# 4  id_001626bd3  com_droga     72   D2  ...      False    False    False     True
#
# [5 rows x 883 columns]

# %%
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
## regressão logística

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state = 376)

modelr = LogisticRegression(max_iter=1000)
modelr.fit(x_treino, y_treino)
modelr.score(x_teste, y_teste)
# Out:
# 0.6267058576527399

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score

modeldum = DummyClassifier('most_frequent')
modeldum.fit(x_treino, y_treino)
modeldum.predict(x_teste)
previsaodum = modeldum.predict(x_teste)
accuracy_score(y_teste, previsaodum)
# Out:
# 0.6067604450976275

# %%
dados_combinados['ativo_moa'].value_counts(normalize = True)
# Out:
# True     0.60666
# False    0.39334
# Name: ativo_moa, dtype: float64

# %%
## árvore de decisão

from sklearn.tree import DecisionTreeClassifier

x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state = 376)

modelarv = DecisionTreeClassifier(max_depth = 3)
modelarv.fit(x_treino, y_treino)
modelarv.score(x_teste, y_teste)
# Out:
# 0.6105395758975436

# %%
x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state = 376)

teste = []
treino = []
for i in range(1,15):
  modelarv = DecisionTreeClassifier(max_depth = i)
  modelarv.fit(x_treino, y_treino)
  teste.append(modelarv.score(x_teste, y_teste))
  treino.append(modelarv.score(x_treino, y_treino))

# %%
teste
# Out:
# [0.6067604450976275,
#  0.6067604450976275,
#  0.6105395758975436,
#  0.6206172580306529,
#  0.6204073063195465,
#  0.6174679823640563,
#  0.6208272097417594,
#  0.6212471131639723,
#  0.6159983203863112,
#  0.612639093008608,
#  0.61074952760865,
#  0.5973126180978375,
#  0.5983623766533698,
#  0.6006718454755406]

# %%
treino
# Out:
# [0.6066348223190384,
#  0.6066348223190384,
#  0.6211222508004829,
#  0.6360820954280615,
#  0.6412261823526324,
#  0.6489423127394888,
#  0.6606477350270327,
#  0.6707259461445594,
#  0.689570101307018,
#  0.7068395359823632,
#  0.7295155109967981,
#  0.752926355571886,
#  0.7771245603905307,
#  0.799223137893024]

# %%
sns.lineplot(x=range(1,15), y=teste, label='teste')
sns.lineplot(x=range(1,15), y=treino, label='treino')
plt.show()

##overfit

# %%
pd.get_dummies(dados_combinados, columns=['dose', 'tratamento', 'tempo'])
# Out:
#                  id   composto     g-0  ...  tempo_24  tempo_48  tempo_72
# 0      id_000644bb2  b68db1d53  1.0620  ...         1         0         0
# 1      id_000779bfc  df89a8e5a  0.0743  ...         0         0         1
# 2      id_000a6266a  18bb41b2c  0.6280  ...         0         1         0
# 3      id_0015fd391  8c7f86626 -0.5138  ...         0         1         0
# 4      id_001626bd3  7cbed3131 -0.3254  ...         0         0         1
# ...             ...        ...     ...  ...       ...       ...       ...
# 23809  id_fffb1ceed  df1d0a5a1  0.1394  ...         1         0         0
# 23810  id_fffb70c0c  ecf3b6b74 -1.3260  ...         1         0         0
# 23811  id_fffc1c3f4  cacb2b860  0.3942  ...         0         1         0
# 23812  id_fffcb9e7c  8b87a7a83  0.6660  ...         1         0         0
# 23813  id_ffffdd77b  972f41291 -0.8598  ...         0         0         1
#
# [23814 rows x 887 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
x = dados_combinados.drop(['id', 'ativo_moa', 'n_moa', 'tratamento', 'dose', 'composto', 'tempo'], axis=1)
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify = y, random_state = 283)

modelo_randomForest1 = RandomForestClassifier()
modelo_randomForest1.fit(x_treino, y_treino)
modelo_randomForest1.score(x_teste, y_teste)
# Out:
# 0.6808733991182028

# %%
x = dados_combinados.drop(['id', 'n_moa', 'ativo_moa', 'composto'], axis = 1)
x = pd.get_dummies(x, columns = ['tratamento', 'dose', 'tempo'])
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=283)

modelo_randomForest2 = RandomForestClassifier()
modelo_randomForest2.fit(x_treino, y_treino)
modelo_randomForest2.score(x_teste, y_teste)
# Out:
# 0.6878018055847155

# %%
from sklearn.ensemble import ExtraTreesClassifier
x = dados_combinados.drop(['id', 'n_moa', 'ativo_moa', 'composto'], axis = 1)
y = dados_combinados['ativo_moa']

clf = ExtraTreesClassifier(n_estimators=10, max_depth=None, min_samples_split=2, random_state=0)

clf.fit(x_treino, y_treino)
clf.score(x_teste, y_teste)
# Out:
# 0.6411925257190846
